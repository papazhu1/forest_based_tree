# %%
import pandas as pd
import numpy as np
from ExperimentSetting import *
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
import os
import glob
warnings.filterwarnings('ignore')

# %%
branch_probability_thresholds=[3000]
filter_approaches = ['probability']
df_names = ['abalone', 'aust_credit', 'balance_scale', 'bank', 'banknote', 
            'biodeg', 'breast cancer', 'car', 'credit', 'cryotherapy', 'ecoli', 
            'forest', 'german', 'glass', 'haberman', 'internet', 'iris', 'kohkiloyeh',
            'liver', 'magic', 'mamographic', 'nurse', 'occupancy', 'pima', 'seismic', 
            'spambase', 'tic-tac-toe', 'vegas', 'winery', 'zoo']
df_names = ['iris']
number_of_estimators=100
fixed_params={}
num_of_iterations=1

e = ExperimentSetting(branch_probability_thresholds,df_names,
                      number_of_estimators,fixed_params, num_of_iterations)

# %%
folder_path = 'pickles_200trees'
files = glob.glob(os.path.join(folder_path, '*'))
# 逐个删除文件
for file in files:
    try:
        os.remove(file)
        print(f"Deleted: {file}")
    except Exception as e:
        print(f"Error deleting {file}: {e}")
e.run()
# Out:
# Deleted: pickles_200trees/iris_0
# {'max_number_of_branches': 3000, 'df_name': 'iris', 'number_of_estimators': 100}
# 0
# 1.0 [4, 15]
# 1.0 [4, 15, 0]
# 1.0 [4, 15, 0, 1]
# 1.0 [4, 15, 0, 1, 7]
# 1.0 [4, 15, 0, 1, 7, 2]
# 1.0 [4, 15, 0, 1, 7, 2, 8]
# 1.0 [4, 15, 0, 1, 7, 2, 8, 3]
# 1.0 [4, 15, 0, 1, 7, 2, 8, 3, 11]
# 1.0 [4, 15, 0, 1, 7, 2, 8, 3, 11, 5]
# Finish pruning
# Iteration 1: 6 conjunctions
# Iteration 2: 16 conjunctions
# Iteration 3: 42 conjunctions
# Iteration 4: 172 conjunctions
# Iteration 5: 283 conjunctions
# Iteration 6: 390 conjunctions
# Iteration 7: 515 conjunctions
# Iteration 8: 619 conjunctions
# Iteration 9: 817 conjunctions
# Final CS size: 1112
# branches_df:
#       0_upper  0_lower  1_upper  1_lower  2_upper  2_lower  3_upper  3_lower  \
# 0        5.30     -inf     2.75     -inf     2.45     -inf     0.70     -inf
# 1        5.30     -inf     2.75     -inf     2.50     2.45     0.70     -inf
# 2        5.30     -inf     2.40     -inf     2.60     2.50     0.70     -inf
# 3        5.30     -inf     2.75     2.40     2.60     2.50     0.70     -inf
# 4        4.95     -inf     2.40     -inf     3.90     2.60     0.70     -inf
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1107      inf     6.15      inf     2.75      inf     5.35     1.75     1.70
# 1108      inf     6.15     2.40     -inf     5.15     5.05      inf     1.75
# 1109      inf     6.15     2.40     -inf      inf     5.15      inf     1.75
# 1110      inf     6.15      inf     2.40     5.15     5.05      inf     1.75
# 1111      inf     6.15      inf     2.40      inf     5.15      inf     1.75
#
#       number_of_samples  branch_probability            probas
# 0             22.292030                 0.0   [9.0, 1.0, 0.0]
# 1             21.645194                 0.0   [8.0, 2.0, 0.0]
# 2              4.965748                 0.0   [7.0, 3.0, 0.0]
# 3              4.965748                 0.0   [7.0, 3.0, 0.0]
# 4              4.050875                 0.0   [6.0, 4.0, 0.0]
# ...                 ...                 ...               ...
# 1107          14.121632                 0.0   [0.0, 2.0, 8.0]
# 1108           8.128095                 0.0   [0.0, 1.0, 9.0]
# 1109          13.738987                 0.0   [0.0, 1.0, 9.0]
# 1110          11.744457                 0.0  [0.0, 0.0, 10.0]
# 1111          19.851756                 0.0  [0.0, 0.0, 10.0]
#
# [1112 rows x 11 columns]
# branches_df_new:
#       0_upper  0_lower  1_upper  1_lower  2_upper  2_lower  3_upper  3_lower  \
# 0        5.30     -inf     2.75     -inf     2.45     -inf     0.70     -inf
# 1        5.30     -inf     2.75     -inf     2.50     2.45     0.70     -inf
# 2        5.30     -inf     2.40     -inf     2.60     2.50     0.70     -inf
# 3        5.30     -inf     2.75     2.40     2.60     2.50     0.70     -inf
# 4        4.95     -inf     2.40     -inf     3.90     2.60     0.70     -inf
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1107      inf     6.15      inf     2.75      inf     5.35     1.75     1.70
# 1108      inf     6.15     2.40     -inf     5.15     5.05      inf     1.75
# 1109      inf     6.15     2.40     -inf      inf     5.15      inf     1.75
# 1110      inf     6.15      inf     2.40     5.15     5.05      inf     1.75
# 1111      inf     6.15      inf     2.40      inf     5.15      inf     1.75
#
#       number_of_samples  branch_probability            probas  setosa  \
# 0             22.292030                 0.0   [9.0, 1.0, 0.0]     9.0
# 1             21.645194                 0.0   [8.0, 2.0, 0.0]     8.0
# 2              4.965748                 0.0   [7.0, 3.0, 0.0]     7.0
# 3              4.965748                 0.0   [7.0, 3.0, 0.0]     7.0
# 4              4.050875                 0.0   [6.0, 4.0, 0.0]     6.0
# ...                 ...                 ...               ...     ...
# 1107          14.121632                 0.0   [0.0, 2.0, 8.0]     0.0
# 1108           8.128095                 0.0   [0.0, 1.0, 9.0]     0.0
# 1109          13.738987                 0.0   [0.0, 1.0, 9.0]     0.0
# 1110          11.744457                 0.0  [0.0, 0.0, 10.0]     0.0
# 1111          19.851756                 0.0  [0.0, 0.0, 10.0]     0.0
#
#       versicolor  virginica
# 0            1.0        0.0
# 1            2.0        0.0
# 2            3.0        0.0
# 3            3.0        0.0
# 4            4.0        0.0
# ...          ...        ...
# 1107         2.0        8.0
# 1108         1.0        9.0
# 1109         1.0        9.0
# 1110         0.0       10.0
# 1111         0.0       10.0
#
# [1112 rows x 14 columns]
# branches_df['probas'].mean()
# [1.65107914 5.16119604 3.18772482]
