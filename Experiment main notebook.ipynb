# %%
import pandas as pd
import numpy as np
from ExperimentSetting import *
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
import os
import glob
warnings.filterwarnings('ignore')

# %%
branch_probability_thresholds=[3000]
filter_approaches = ['probability']
df_names = ['abalone', 'aust_credit', 'balance_scale', 'bank', 'banknote', 
            'biodeg', 'breast cancer', 'car', 'credit', 'cryotherapy', 'ecoli', 
            'forest', 'german', 'glass', 'haberman', 'internet', 'iris', 'kohkiloyeh',
            'liver', 'magic', 'mamographic', 'nurse', 'occupancy', 'pima', 'seismic', 
            'spambase', 'tic-tac-toe', 'vegas', 'winery', 'zoo']
df_names = ['iris']
number_of_estimators=100
fixed_params={}
num_of_iterations=1

e = ExperimentSetting(branch_probability_thresholds,df_names,
                      number_of_estimators,fixed_params, num_of_iterations)

# %%
folder_path = 'pickles_200trees'
files = glob.glob(os.path.join(folder_path, '*'))
# 逐个删除文件
for file in files:
    try:
        os.remove(file)
        print(f"Deleted: {file}")
    except Exception as e:
        print(f"Error deleting {file}: {e}")
e.run()
# Out:
# Deleted: pickles_200trees/iris_0
# {'max_number_of_branches': 3000, 'df_name': 'iris', 'number_of_estimators': 100}
# 0
# 1.0 [62, 32]
# 1.0 [62, 32, 11]
# 1.0 [62, 32, 11, 1]
# 1.0 [62, 32, 11, 1, 2]
# 1.0 [62, 32, 11, 1, 2, 3]
# 1.0 [62, 32, 11, 1, 2, 3, 7]
# 1.0 [62, 32, 11, 1, 2, 3, 7, 9]
# 1.0 [62, 32, 11, 1, 2, 3, 7, 9, 12]
# 1.0 [62, 32, 11, 1, 2, 3, 7, 9, 12, 0]
# Finish pruning
# Iteration 1: 4 conjunctions
# Iteration 2: 18 conjunctions
# Iteration 3: 41 conjunctions
# Iteration 4: 169 conjunctions
# Iteration 5: 380 conjunctions
# Iteration 6: 623 conjunctions
# Iteration 7: 864 conjunctions
# Iteration 8: 1049 conjunctions
# Iteration 9: 1386 conjunctions
# Final CS size: 1839
# branches_df:
#       0_upper  0_lower  1_upper  1_lower  2_upper  2_lower  3_upper  3_lower  \
# 0        4.85     -inf     3.35     -inf     2.45     -inf      0.7     -inf
# 1        4.95     4.85     3.35     -inf     2.45     -inf      0.7     -inf
# 2        5.45     4.95     3.35     -inf     2.45     -inf      0.7     -inf
# 3        5.45     -inf      inf     3.35     2.45     -inf      0.7     -inf
# 4        6.15     5.45     3.35     -inf     2.45     -inf      0.7     -inf
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1834      inf     6.15      inf     3.50     5.05     4.85      inf     1.75
# 1835     6.15     6.00      inf     3.50     5.15     5.05      inf     1.75
# 1836      inf     6.15      inf     3.50     5.15     5.05      inf     1.75
# 1837     6.15     6.00      inf     3.50      inf     5.15      inf     1.75
# 1838      inf     6.15      inf     3.50      inf     5.15      inf     1.75
#
#       number_of_samples  branch_probability  \
# 0              28.86814                 0.0
# 1              28.58698                 0.0
# 2              29.09422                 0.0
# 3              29.05519                 0.0
# 4              28.89130                 0.0
# ...                 ...                 ...
# 1834           15.63672                 0.0
# 1835           14.75904                 0.0
# 1836           17.65893                 0.0
# 1837           15.02973                 0.0
# 1838           17.98280                 0.0
#
#                                                  probas
# 0                                      [10.0, 0.0, 0.0]
# 1          [9.333333333333334, 0.0, 0.6666666666666666]
# 2     [9.026315789473685, 0.868421052631579, 0.10526...
# 3                                      [10.0, 0.0, 0.0]
# 4     [9.026315789473685, 0.868421052631579, 0.10526...
# ...                                                 ...
# 1834                                    [0.0, 1.0, 9.0]
# 1835                                   [0.0, 0.0, 10.0]
# 1836                                   [0.0, 0.0, 10.0]
# 1837                                   [0.0, 0.0, 10.0]
# 1838                                   [0.0, 0.0, 10.0]
#
# [1839 rows x 11 columns]
# branches_df[rf.classes_[i]]:
# 0       10.000000
# 1        9.333333
# 2        9.026316
# 3       10.000000
# 4        9.026316
#           ...
# 1834     0.000000
# 1835     0.000000
# 1836     0.000000
# 1837     0.000000
# 1838     0.000000
# Name: setosa, Length: 1839, dtype: float64
#
# branches_df[rf.classes_[i]]:
# 0       0.000000
# 1       0.000000
# 2       0.868421
# 3       0.000000
# 4       0.868421
#           ...
# 1834    1.000000
# 1835    0.000000
# 1836    0.000000
# 1837    0.000000
# 1838    0.000000
# Name: versicolor, Length: 1839, dtype: float64
#
# branches_df[rf.classes_[i]]:
# 0        0.000000
# 1        0.666667
# 2        0.105263
# 3        0.000000
# 4        0.105263
#           ...
# 1834     9.000000
# 1835    10.000000
# 1836    10.000000
# 1837    10.000000
# 1838    10.000000
# Name: virginica, Length: 1839, dtype: float64
#
# branches_df_new:
#       0_upper  0_lower  1_upper  1_lower  2_upper  2_lower  3_upper  3_lower  \
# 0        4.85     -inf     3.35     -inf     2.45     -inf      0.7     -inf
# 1        4.95     4.85     3.35     -inf     2.45     -inf      0.7     -inf
# 2        5.45     4.95     3.35     -inf     2.45     -inf      0.7     -inf
# 3        5.45     -inf      inf     3.35     2.45     -inf      0.7     -inf
# 4        6.15     5.45     3.35     -inf     2.45     -inf      0.7     -inf
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1834      inf     6.15      inf     3.50     5.05     4.85      inf     1.75
# 1835     6.15     6.00      inf     3.50     5.15     5.05      inf     1.75
# 1836      inf     6.15      inf     3.50     5.15     5.05      inf     1.75
# 1837     6.15     6.00      inf     3.50      inf     5.15      inf     1.75
# 1838      inf     6.15      inf     3.50      inf     5.15      inf     1.75
#
#       number_of_samples  branch_probability  \
# 0              28.86814                 0.0
# 1              28.58698                 0.0
# 2              29.09422                 0.0
# 3              29.05519                 0.0
# 4              28.89130                 0.0
# ...                 ...                 ...
# 1834           15.63672                 0.0
# 1835           14.75904                 0.0
# 1836           17.65893                 0.0
# 1837           15.02973                 0.0
# 1838           17.98280                 0.0
#
#                                                  probas     setosa  \
# 0                                      [10.0, 0.0, 0.0]  10.000000
# 1          [9.333333333333334, 0.0, 0.6666666666666666]   9.333333
# 2     [9.026315789473685, 0.868421052631579, 0.10526...   9.026316
# 3                                      [10.0, 0.0, 0.0]  10.000000
# 4     [9.026315789473685, 0.868421052631579, 0.10526...   9.026316
# ...                                                 ...        ...
# 1834                                    [0.0, 1.0, 9.0]   0.000000
# 1835                                   [0.0, 0.0, 10.0]   0.000000
# 1836                                   [0.0, 0.0, 10.0]   0.000000
# 1837                                   [0.0, 0.0, 10.0]   0.000000
# 1838                                   [0.0, 0.0, 10.0]   0.000000
#
#       versicolor  virginica
# 0       0.000000   0.000000
# 1       0.000000   0.666667
# 2       0.868421   0.105263
# 3       0.000000   0.000000
# 4       0.868421   0.105263
# ...          ...        ...
# 1834    1.000000   9.000000
# 1835    0.000000  10.000000
# 1836    0.000000  10.000000
# 1837    0.000000  10.000000
# 1838    0.000000  10.000000
#
# [1839 rows x 14 columns]
