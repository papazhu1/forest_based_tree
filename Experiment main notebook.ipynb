# %%
import pandas as pd
import numpy as np
from ExperimentSetting import *
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
import os
import glob
warnings.filterwarnings('ignore')

# %%
branch_probability_thresholds=[3000]
filter_approaches = ['probability']
df_names = ['abalone', 'aust_credit', 'balance_scale', 'bank', 'banknote', 
            'biodeg', 'breast cancer', 'car', 'credit', 'cryotherapy', 'ecoli', 
            'forest', 'german', 'glass', 'haberman', 'internet', 'iris', 'kohkiloyeh',
            'liver', 'magic', 'mamographic', 'nurse', 'occupancy', 'pima', 'seismic', 
            'spambase', 'tic-tac-toe', 'vegas', 'winery', 'zoo']
df_names = ['iris']
number_of_estimators=100
fixed_params={}
num_of_iterations=30

e = ExperimentSetting(branch_probability_thresholds,df_names,
                                     number_of_estimators,fixed_params)

# %%
folder_path = 'pickles_200trees'
files = glob.glob(os.path.join(folder_path, '*'))
# 逐个删除文件
for file in files:
    try:
        os.remove(file)
        print(f"Deleted: {file}")
    except Exception as e:
        print(f"Error deleting {file}: {e}")
e.run()
# Out:
# Deleted: pickles_200trees/iris_0
# {'max_number_of_branches': 3000, 'df_name': 'iris', 'number_of_estimators': 100}
# 0
# 0.9999826388888889 [22, 25]
# 1.0 [22, 25, 1]
# 1.0 [22, 25, 1, 4]
# 1.0 [22, 25, 1, 4, 0]
# 1.0 [22, 25, 1, 4, 0, 2]
# 1.0 [22, 25, 1, 4, 0, 2, 3]
# 1.0 [22, 25, 1, 4, 0, 2, 3, 15]
# 1.0 [22, 25, 1, 4, 0, 2, 3, 15, 5]
# 1.0 [22, 25, 1, 4, 0, 2, 3, 15, 5, 6]
# Finish pruning
# Iteration 1: 7 conjunctions
# Iteration 2: 29 conjunctions
# Iteration 3: 83 conjunctions
# Iteration 4: 267 conjunctions
# Iteration 5: 363 conjunctions
# Iteration 6: 521 conjunctions
# Iteration 7: 767 conjunctions
# Iteration 8: 1076 conjunctions
# Iteration 9: 1208 conjunctions
# Final CS size: 1511
# branches_df       0_upper  0_lower  1_upper  1_lower  2_upper  2_lower  3_upper  3_lower  \
# 0         4.7     -inf     2.85     -inf     2.35     -inf     0.70     -inf
# 1         4.7     -inf     2.85     -inf     2.45     2.35     0.70     -inf
# 2         4.7     -inf     2.85     -inf     4.20     2.45     0.70     -inf
# 3         4.7     -inf     2.85     -inf     4.95     4.20     0.70     -inf
# 4         4.7     -inf     2.65     -inf      inf     4.95     0.70     -inf
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1506      inf     6.95     2.75     -inf      inf     5.20     1.70     1.65
# 1507      inf     6.95     2.75     -inf      inf     5.20     1.75     1.70
# 1508      inf     6.95      inf     2.75      inf     5.20     1.75     1.65
# 1509      inf     6.25     2.75     -inf      inf     5.20      inf     1.75
# 1510      inf     6.25      inf     2.75      inf     5.20      inf     1.75
#
#       number_of_samples  branch_probability            probas
# 0              27.91779             0.04688  [10.0, 0.0, 0.0]
# 1              21.92392             0.00000   [8.0, 2.0, 0.0]
# 2              19.09548             0.02344   [7.0, 3.0, 0.0]
# 3              15.61562             0.00000   [7.0, 2.0, 1.0]
# 4               2.45629             0.01172   [7.0, 0.0, 3.0]
# ...                 ...                 ...               ...
# 1506            2.58450             0.00000   [0.0, 2.0, 8.0]
# 1507            2.81841             0.00000   [0.0, 1.0, 9.0]
# 1508            3.65503             0.00000   [0.0, 2.0, 8.0]
# 1509           10.74716             0.00000  [0.0, 0.0, 10.0]
# 1510           13.93734             0.00000  [0.0, 0.0, 10.0]
#
# [1511 rows x 11 columns]
# branches_df[rf.classes_[i]] 0       10.0
# 1        8.0
# 2        7.0
# 3        7.0
# 4        7.0
#         ...
# 1506     0.0
# 1507     0.0
# 1508     0.0
# 1509     0.0
# 1510     0.0
# Name: setosa, Length: 1511, dtype: float64
# branches_df[rf.classes_[i]] 0       0.0
# 1       2.0
# 2       3.0
# 3       2.0
# 4       0.0
#        ...
# 1506    2.0
# 1507    1.0
# 1508    2.0
# 1509    0.0
# 1510    0.0
# Name: versicolor, Length: 1511, dtype: float64
# 1
# 0.9999826388888889 [29, 8]
# 1.0 [29, 8, 5]
# 1.0 [29, 8, 5, 11]
# 1.0 [29, 8, 5, 11, 0]
# 1.0 [29, 8, 5, 11, 0, 2]
# 1.0 [29, 8, 5, 11, 0, 2, 3]
# 1.0 [29, 8, 5, 11, 0, 2, 3, 6]
# 1.0 [29, 8, 5, 11, 0, 2, 3, 6, 7]
# 1.0 [29, 8, 5, 11, 0, 2, 3, 6, 7, 4]
# Finish pruning
# Iteration 1: 9 conjunctions
# Iteration 2: 41 conjunctions
# Iteration 3: 94 conjunctions
# Iteration 4: 179 conjunctions
# Iteration 5: 301 conjunctions
# Iteration 6: 472 conjunctions
# Iteration 7: 755 conjunctions
# Iteration 8: 895 conjunctions
# Iteration 9: 1116 conjunctions
# Final CS size: 1710
# branches_df       0_upper  0_lower  1_upper  1_lower  2_upper  2_lower  3_upper  3_lower  \
# 0        5.45     -inf     2.80     -inf     2.30     -inf     0.70     -inf
# 1        4.95     -inf     2.45     -inf     2.30     -inf     0.75     0.70
# 2        4.95     -inf     2.80     2.45     2.30     -inf     0.75     0.70
# 3        5.45     4.95     2.80     -inf     2.30     -inf     0.75     0.70
# 4        5.45     -inf     2.80     -inf     2.35     2.30     0.70     -inf
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1705     7.10     6.50      inf     3.25      inf     5.05     1.75     0.80
# 1706      inf     7.10      inf     3.25      inf     5.05     1.75     0.80
# 1707      inf     6.05     3.15     -inf      inf     5.05      inf     1.75
# 1708     6.10     6.05      inf     3.15      inf     5.05      inf     1.75
# 1709      inf     6.10      inf     3.15      inf     5.05      inf     1.75
#
#       number_of_samples  branch_probability  \
# 0              13.06189             0.00000
# 1               2.85034             0.00000
# 2               2.85034             0.00000
# 3              13.66974             0.00000
# 4              14.57875             0.00000
# ...                 ...                 ...
# 1705            4.69490             0.00000
# 1706            3.31980             0.00000
# 1707           19.37498             0.02344
# 1708            4.56673             0.00000
# 1709           12.91665             0.02344
#
#                                             probas
# 0                                  [7.0, 3.0, 0.0]
# 1                                  [6.0, 4.0, 0.0]
# 2                                  [6.0, 3.0, 1.0]
# 3                                  [6.0, 4.0, 0.0]
# 4                                  [6.0, 4.0, 0.0]
# ...                                            ...
# 1705  [0.0, 3.7857142857142856, 6.214285714285714]
# 1706  [0.0, 3.2857142857142856, 6.714285714285714]
# 1707                              [0.0, 0.0, 10.0]
# 1708                               [0.0, 1.0, 9.0]
# 1709                              [0.0, 0.0, 10.0]
#
# [1710 rows x 11 columns]
# branches_df[rf.classes_[i]] 0       7.0
# 1       6.0
# 2       6.0
# 3       6.0
# 4       6.0
#        ...
# 1705    0.0
# 1706    0.0
# 1707    0.0
# 1708    0.0
# 1709    0.0
# Name: setosa, Length: 1710, dtype: float64
# branches_df[rf.classes_[i]] 0       3.000000
# 1       4.000000
# 2       3.000000
# 3       4.000000
# 4       4.000000
#           ...
# 1705    3.785714
# 1706    3.285714
# 1707    0.000000
# 1708    1.000000
# 1709    0.000000
# Name: versicolor, Length: 1710, dtype: float64
# 2
# 1.0 [45, 5]
# 1.0 [45, 5, 0]
# 1.0 [45, 5, 0, 4]
# 1.0 [45, 5, 0, 4, 1]
# 1.0 [45, 5, 0, 4, 1, 6]
# 1.0 [45, 5, 0, 4, 1, 6, 7]
# 1.0 [45, 5, 0, 4, 1, 6, 7, 2]
# 1.0 [45, 5, 0, 4, 1, 6, 7, 2, 8]
# 1.0 [45, 5, 0, 4, 1, 6, 7, 2, 8, 3]
# Finish pruning
# Iteration 1: 6 conjunctions
# Iteration 2: 18 conjunctions
# Iteration 3: 40 conjunctions
# Iteration 4: 40 conjunctions
# Iteration 5: 68 conjunctions
# Iteration 6: 218 conjunctions
# Iteration 7: 438 conjunctions
# Iteration 8: 702 conjunctions
# Iteration 9: 921 conjunctions
# Final CS size: 1108
# branches_df       0_upper  0_lower  1_upper  1_lower  2_upper  2_lower  3_upper  3_lower  \
# 0         inf     -inf      inf     -inf     2.45     -inf     0.75     -inf
# 1         inf     -inf      inf     -inf     2.45     -inf     0.80     0.75
# 2         inf     -inf      inf     -inf     2.65     2.45     0.75     -inf
# 3         inf     -inf      inf     -inf     2.65     2.45     0.80     0.75
# 4         inf     -inf      2.3     -inf     2.70     2.65     0.75     -inf
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1103     6.15     6.05      3.1     -inf      inf     4.95      inf     1.85
# 1104     5.95     4.95      inf      3.1      inf     4.95      inf     1.85
# 1105     6.05     5.95      inf      3.1      inf     4.95      inf     1.85
# 1106     6.15     6.05      inf      3.1      inf     4.95      inf     1.85
# 1107      inf     6.15      inf     -inf      inf     4.95      inf     1.85
#
#       number_of_samples  branch_probability  \
# 0              28.06091               0.125
# 1              23.09567               0.000
# 2              27.75736               0.000
# 3              22.84583               0.000
# 4              22.88109               0.000
# ...                 ...                 ...
# 1103           18.09606               0.000
# 1104           12.55629               0.000
# 1105           12.69188               0.000
# 1106           17.02843               0.000
# 1107           18.66963               0.000
#
#                                             probas
# 0                                 [10.0, 0.0, 0.0]
# 1                                  [9.0, 1.0, 0.0]
# 2                                  [9.0, 1.0, 0.0]
# 3                                  [8.0, 2.0, 0.0]
# 4                                  [8.0, 1.0, 1.0]
# ...                                            ...
# 1103                               [0.0, 0.1, 9.9]
# 1104                               [0.0, 1.0, 9.0]
# 1105  [0.0, 1.6666666666666665, 8.333333333333332]
# 1106                               [0.0, 1.0, 9.0]
# 1107                              [0.0, 0.0, 10.0]
#
# [1108 rows x 11 columns]
# branches_df[rf.classes_[i]] 0       10.0
# 1        9.0
# 2        9.0
# 3        8.0
# 4        8.0
#         ...
# 1103     0.0
# 1104     0.0
# 1105     0.0
# 1106     0.0
# 1107     0.0
# Name: setosa, Length: 1108, dtype: float64
# branches_df[rf.classes_[i]] 0       0.000000
# 1       1.000000
# 2       1.000000
# 3       2.000000
# 4       1.000000
#           ...
# 1103    0.100000
# 1104    1.000000
# 1105    1.666667
# 1106    1.000000
# 1107    0.000000
# Name: versicolor, Length: 1108, dtype: float64
# 3
# 1.0 [20, 25]
# 1.0 [20, 25, 0]
# 1.0 [20, 25, 0, 2]
# 1.0 [20, 25, 0, 2, 3]
# 1.0000000000000002 [20, 25, 0, 2, 3, 39]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/nh/wwy8_3vs2tj7zp23_03pkxmc0000gn/T/ipykernel_54318/1105805618.py in <module>
#       8     except Exception as e:
#       9         print(f"Error deleting {file}: {e}")
# ---> 10 e.run()
#
# ~/Documents/GitHub/forest_based_tree/ExperimentSetting.py in run(self)
#      36                 d['number_of_estimators'] = self.number_of_estimators
#      37                 print(d)
# ---> 38                 self.run_experiment(threshold, df, x_columns, y_column, feature_types, d)
#      39     def run_experiment(self,branch_probability_threshold,df,x_columns,y_column,feature_types,hyper_parameters_dict):
#      40         for i in range(self.num_of_iterations):
#
# ~/Documents/GitHub/forest_based_tree/ExperimentSetting.py in run_experiment(self, branch_probability_threshold, df, x_columns, y_column, feature_types, hyper_parameters_dict)
#      66             #Create the conjunction set
#      67             start_temp = datetime.datetime.now()
# ---> 68             cs = ConjunctionSet(x_columns, trainAndValidation_x,trainAndValidation_x,trainAndValidation_y, rf, feature_types,
#      69                                 hyper_parameters_dict['max_number_of_branches'])
#      70             result_dict['conjunction set training time'] = (datetime.datetime.now() - start_temp).total_seconds()
#
# ~/Documents/GitHub/forest_based_tree/ConjunctionSet.py in __init__(self, feature_names, original_data, pruning_x, pruning_y, model, feature_types, amount_of_branches_threshold, filter_approach, exclusion_starting_point, minimal_forest_size, exclusion_threshold)
#      18         self.exclusion_threshold = exclusion_threshold
#      19         self.label_names = model.classes_
# ---> 20         self.relevant_indexes = reduce_error_pruning(self.model, pruning_x, pruning_y, minimal_forest_size)
#      21         self.feature_types = feature_types
#      22         self.filter_approach = filter_approach
#
# ~/Documents/GitHub/forest_based_tree/pruningFunctions.py in reduce_error_pruning(model, validation_x, validation_y, min_size)
#      30     best_auc,current_indexes = select_index(model,[],validation_x,validation_y)
#      31     while len(current_indexes) <= model.n_estimators:
# ---> 32         new_auc, new_current_indexes = select_index(model, current_indexes,validation_x,validation_y)
#      33         if new_auc <= best_auc and len(new_current_indexes) > min_size:
#      34             break
#
# ~/Documents/GitHub/forest_based_tree/pruningFunctions.py in select_index(rf, current_indexes, validation_x, validation_y)
#      22         if i in current_indexes:
#      23             continue
# ---> 24         predictions = predict_with_included_trees(rf,current_indexes+[i],validation_x)
#      25         options_auc[i] = get_auc(validation_y,predictions,rf.classes_)
#      26     best_index = max(options_auc, key=options_auc.get)
#
# ~/Documents/GitHub/forest_based_tree/pruningFunctions.py in predict_with_included_trees(model, included_indexes, X)
#       9     predictions=[]
#      10     for inst in X:
# ---> 11         predictions.append(predict_instance_with_included_tree(model,included_indexes,inst))
#      12     return np.array(predictions)
#      13 def predict_instance_with_included_tree(model,included_indexes,inst):
#
# ~/Documents/GitHub/forest_based_tree/pruningFunctions.py in predict_instance_with_included_tree(model, included_indexes, inst)
#      15     for i,t in enumerate(model.estimators_):
#      16         if i in included_indexes:
# ---> 17             v = v + t.predict_proba(inst.reshape(1, -1))[0]
#      18     return v/np.sum(v)
#      19 def select_index(rf,current_indexes,validation_x,validation_y):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py in predict_proba(self, X, check_input)
#     969         """
#     970         check_is_fitted(self)
# --> 971         X = self._validate_X_predict(X, check_input)
#     972         proba = self.tree_.predict(X)
#     973
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py in _validate_X_predict(self, X, check_input)
#     431         """Validate the training data on predict (probabilities)."""
#     432         if check_input:
# --> 433             X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     434             if issparse(X) and (
#     435                 X.indices.dtype != np.intc or X.indptr.dtype != np.intc
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     583
#     584         if not no_val_X and check_params.get("ensure_2d", True):
# --> 585             self._check_n_features(X, reset=reset)
#     586
#     587         return out
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in _check_n_features(self, X, reset)
#     374                should set `reset=False`.
#     375         """
# --> 376         try:
#     377             n_features = _num_features(X)
#     378         except TypeError as e:
#
# KeyboardInterrupt:
