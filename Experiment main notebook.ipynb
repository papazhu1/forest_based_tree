# %%
import pandas as pd
import numpy as np
from ExperimentSetting import *
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
import os
import glob
warnings.filterwarnings('ignore')

# %%
branch_probability_thresholds=[3000]
filter_approaches = ['probability']
df_names = ['abalone', 'aust_credit', 'balance_scale', 'bank', 'banknote', 
            'biodeg', 'breast cancer', 'car', 'credit', 'cryotherapy', 'ecoli', 
            'forest', 'german', 'glass', 'haberman', 'internet', 'iris', 'kohkiloyeh',
            'liver', 'magic', 'mamographic', 'nurse', 'occupancy', 'pima', 'seismic', 
            'spambase', 'tic-tac-toe', 'vegas', 'winery', 'zoo']
df_names = ['iris']
number_of_estimators=100
fixed_params={}
num_of_iterations=1

e = ExperimentSetting(branch_probability_thresholds,df_names,
                      number_of_estimators,fixed_params, num_of_iterations)

# %%
folder_path = 'pickles_200trees'
files = glob.glob(os.path.join(folder_path, '*'))
# 逐个删除文件
for file in files:
    try:
        os.remove(file)
        print(f"Deleted: {file}")
    except Exception as e:
        print(f"Error deleting {file}: {e}")
e.run()
# Out:
# Deleted: pickles_200trees/iris_0
# {'max_number_of_branches': 3000, 'df_name': 'iris', 'number_of_estimators': 100}
# 0
# 1.0 [43, 30]
# 1.0 [43, 30, 0]
# 1.0 [43, 30, 0, 1]
# 1.0 [43, 30, 0, 1, 2]
# 1.0 [43, 30, 0, 1, 2, 4]
# 1.0 [43, 30, 0, 1, 2, 4, 6]
# 1.0 [43, 30, 0, 1, 2, 4, 6, 5]
# 1.0 [43, 30, 0, 1, 2, 4, 6, 5, 7]
# 1.0 [43, 30, 0, 1, 2, 4, 6, 5, 7, 3]
# Finish pruning
# Iteration 1: 10 conjunctions
# Iteration 2: 20 conjunctions
# Iteration 3: 40 conjunctions
# Iteration 4: 95 conjunctions
# Iteration 5: 164 conjunctions
# Iteration 6: 297 conjunctions
# Iteration 7: 297 conjunctions
# Iteration 8: 444 conjunctions
# Iteration 9: 604 conjunctions
# Final CS size: 748
# branches_df:
#      0_upper  0_lower  1_upper  1_lower  2_upper  2_lower  3_upper  3_lower  \
# 0       4.75     -inf      2.6     -inf     2.50     -inf     0.70     -inf
# 1       4.75     -inf      2.6     -inf     3.90     2.50     0.70     -inf
# 2       4.75     -inf      2.6     -inf     4.85     3.90     0.70     -inf
# 3       4.75     -inf      2.6     -inf     5.05     4.85     0.70     -inf
# 4       4.75     -inf      2.6     -inf     5.35     5.05     0.70     -inf
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 743      inf      6.6      inf     3.15     5.65     5.35     1.75     1.70
# 744      inf      6.6      inf     3.15      inf     5.65     1.75     1.70
# 745      inf      6.6      inf     3.15     5.65     4.85     1.85     1.75
# 746      inf      6.6      inf     3.15      inf     5.65     1.85     1.75
# 747      inf      6.6      inf     3.15      inf     4.85      inf     1.85
#
#      number_of_samples  branch_probability  \
# 0            25.620312            0.015625
# 1            14.821390            0.007813
# 2            14.821390            0.000000
# 3            16.162840            0.007813
# 4            16.162840            0.000000
# ..                 ...                 ...
# 743           1.502376            0.000000
# 744           1.502376            0.000000
# 745          10.463153            0.000000
# 746          10.463153            0.000000
# 747          22.622102            0.000000
#
#                                            probas
# 0                                [10.0, 0.0, 0.0]
# 1                                 [8.0, 2.0, 0.0]
# 2                                 [8.0, 1.0, 1.0]
# 3                                 [8.0, 2.0, 0.0]
# 4                                 [8.0, 1.0, 1.0]
# ..                                            ...
# 743  [0.0, 2.9444444444444446, 7.055555555555555]
# 744  [0.0, 1.9444444444444444, 8.055555555555555]
# 745                               [0.0, 2.0, 8.0]
# 746                               [0.0, 1.0, 9.0]
# 747                              [0.0, 0.0, 10.0]
#
# [748 rows x 11 columns]
# branches_df[rf.classes_[i]]:
# 0      10.0
# 1       8.0
# 2       8.0
# 3       8.0
# 4       8.0
#        ...
# 743     0.0
# 744     0.0
# 745     0.0
# 746     0.0
# 747     0.0
# Name: setosa, Length: 748, dtype: float64
#
# branches_df[rf.classes_[i]]:
# 0      0.000000
# 1      2.000000
# 2      1.000000
# 3      2.000000
# 4      1.000000
#          ...
# 743    2.944444
# 744    1.944444
# 745    2.000000
# 746    1.000000
# 747    0.000000
# Name: versicolor, Length: 748, dtype: float64
#
# branches_df[rf.classes_[i]]:
# 0       0.000000
# 1       0.000000
# 2       1.000000
# 3       0.000000
# 4       1.000000
#          ...
# 743     7.055556
# 744     8.055556
# 745     8.000000
# 746     9.000000
# 747    10.000000
# Name: virginica, Length: 748, dtype: float64
#
# branches_df_new:
#      0_upper  0_lower  1_upper  1_lower  2_upper  2_lower  3_upper  3_lower  \
# 0       4.75     -inf      2.6     -inf     2.50     -inf     0.70     -inf
# 1       4.75     -inf      2.6     -inf     3.90     2.50     0.70     -inf
# 2       4.75     -inf      2.6     -inf     4.85     3.90     0.70     -inf
# 3       4.75     -inf      2.6     -inf     5.05     4.85     0.70     -inf
# 4       4.75     -inf      2.6     -inf     5.35     5.05     0.70     -inf
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 743      inf      6.6      inf     3.15     5.65     5.35     1.75     1.70
# 744      inf      6.6      inf     3.15      inf     5.65     1.75     1.70
# 745      inf      6.6      inf     3.15     5.65     4.85     1.85     1.75
# 746      inf      6.6      inf     3.15      inf     5.65     1.85     1.75
# 747      inf      6.6      inf     3.15      inf     4.85      inf     1.85
#
#      number_of_samples  branch_probability  \
# 0            25.620312            0.015625
# 1            14.821390            0.007813
# 2            14.821390            0.000000
# 3            16.162840            0.007813
# 4            16.162840            0.000000
# ..                 ...                 ...
# 743           1.502376            0.000000
# 744           1.502376            0.000000
# 745          10.463153            0.000000
# 746          10.463153            0.000000
# 747          22.622102            0.000000
#
#                                            probas  setosa  versicolor  \
# 0                                [10.0, 0.0, 0.0]    10.0    0.000000
# 1                                 [8.0, 2.0, 0.0]     8.0    2.000000
# 2                                 [8.0, 1.0, 1.0]     8.0    1.000000
# 3                                 [8.0, 2.0, 0.0]     8.0    2.000000
# 4                                 [8.0, 1.0, 1.0]     8.0    1.000000
# ..                                            ...     ...         ...
# 743  [0.0, 2.9444444444444446, 7.055555555555555]     0.0    2.944444
# 744  [0.0, 1.9444444444444444, 8.055555555555555]     0.0    1.944444
# 745                               [0.0, 2.0, 8.0]     0.0    2.000000
# 746                               [0.0, 1.0, 9.0]     0.0    1.000000
# 747                              [0.0, 0.0, 10.0]     0.0    0.000000
#
#      virginica
# 0     0.000000
# 1     0.000000
# 2     1.000000
# 3     0.000000
# 4     1.000000
# ..         ...
# 743   7.055556
# 744   8.055556
# 745   8.000000
# 746   9.000000
# 747  10.000000
#
# [748 rows x 14 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/nh/wwy8_3vs2tj7zp23_03pkxmc0000gn/T/ipykernel_59146/1105805618.py in <module>
#       8     except Exception as e:
#       9         print(f"Error deleting {file}: {e}")
# ---> 10 e.run()
#
# ~/Documents/GitHub/forest_based_tree/ExperimentSetting.py in run(self)
#      36                 d['number_of_estimators'] = self.number_of_estimators
#      37                 print(d)
# ---> 38                 self.run_experiment(threshold, df, x_columns, y_column, feature_types, d)
#      39     def run_experiment(self,branch_probability_threshold,df,x_columns,y_column,feature_types,hyper_parameters_dict):
#      40         for i in range(self.num_of_iterations):
#
# ~/Documents/GitHub/forest_based_tree/ExperimentSetting.py in run_experiment(self, branch_probability_threshold, df, x_columns, y_column, feature_types, hyper_parameters_dict)
#      98
#      99                 # 对DataFrame取一整列是Series类型，而加.values()后就变成了list类型
# --> 100                 df_dict[col] = branches_df[col].values()
#     101                 print("df_dict[col]:")
#     102                 print(type(df_dict[col]))
#
# TypeError: 'numpy.ndarray' object is not callable
