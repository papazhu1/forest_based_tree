# %%
import pandas as pd
import numpy as np
from ExperimentSetting import *
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
import os
import glob
warnings.filterwarnings('ignore')

# %%
branch_probability_thresholds=[3000]
filter_approaches = ['probability']
df_names = ['abalone', 'aust_credit', 'balance_scale', 'bank', 'banknote', 
            'biodeg', 'breast cancer', 'car', 'credit', 'cryotherapy', 'ecoli', 
            'forest', 'german', 'glass', 'haberman', 'internet', 'iris', 'kohkiloyeh',
            'liver', 'magic', 'mamographic', 'nurse', 'occupancy', 'pima', 'seismic', 
            'spambase', 'tic-tac-toe', 'vegas', 'winery', 'zoo']
df_names = ['iris']
number_of_estimators=100
fixed_params={}
num_of_iterations=1

e = ExperimentSetting(branch_probability_thresholds,df_names,
                      number_of_estimators,fixed_params, num_of_iterations)

# %%
folder_path = 'pickles_200trees'
files = glob.glob(os.path.join(folder_path, '*'))
# 逐个删除文件
for file in files:
    try:
        os.remove(file)
        print(f"Deleted: {file}")
    except Exception as e:
        print(f"Error deleting {file}: {e}")
e.run()
# Out:
# Deleted: pickles_200trees/iris_0
# {'max_number_of_branches': 3000, 'df_name': 'iris', 'number_of_estimators': 100}
# 0
# 1.0 [45, 22]
# 1.0 [45, 22, 0]
# 1.0 [45, 22, 0, 2]
# 1.0 [45, 22, 0, 2, 1]
# 1.0 [45, 22, 0, 2, 1, 3]
# 1.0 [45, 22, 0, 2, 1, 3, 4]
# 1.0 [45, 22, 0, 2, 1, 3, 4, 5]
# 1.0 [45, 22, 0, 2, 1, 3, 4, 5, 6]
# 1.0 [45, 22, 0, 2, 1, 3, 4, 5, 6, 7]
# Finish pruning
# Iteration 1: 7 conjunctions
# Iteration 2: 17 conjunctions
# Iteration 3: 50 conjunctions
# Iteration 4: 226 conjunctions
# Iteration 5: 322 conjunctions
# Iteration 6: 456 conjunctions
# Iteration 7: 720 conjunctions
# Iteration 8: 1093 conjunctions
# Iteration 9: 1505 conjunctions
# Final CS size: 1610
# branches_df:
#       0_upper  0_lower  1_upper  1_lower  2_upper  2_lower  3_upper  3_lower  \
# 0        5.45     -inf     2.15     -inf     2.45     -inf      0.7     -inf
# 1        5.45     -inf     2.15     -inf     2.60     2.45      0.7     -inf
# 2        5.05     -inf     2.15     -inf     3.90     2.60      0.7     -inf
# 3        5.05     -inf     2.15     -inf     4.85     3.90      0.7     -inf
# 4        5.45     5.05     2.15     -inf     4.85     2.60      0.7     -inf
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1605     6.00     5.95      inf     2.75      inf     4.95      inf      1.7
# 1606     6.45     6.00      inf     2.75     4.95     4.85      inf      1.7
# 1607     7.00     6.45      inf     2.75     4.95     4.85      inf      1.7
# 1608     7.00     6.00      inf     2.75      inf     4.95      inf      1.7
# 1609      inf     7.00      inf     2.75      inf     4.85      inf      1.7
#
#       number_of_samples  branch_probability            probas
# 0              23.92448             0.02344   [9.0, 1.0, 0.0]
# 1              19.35746             0.00000   [8.0, 2.0, 0.0]
# 2              12.94511             0.02344   [6.0, 4.0, 0.0]
# 3              12.94511             0.02344   [6.0, 3.0, 1.0]
# 4              18.94014             0.00000   [6.0, 4.0, 0.0]
# ...                 ...                 ...               ...
# 1605           19.61608             0.00000  [0.0, 0.0, 10.0]
# 1606           17.46240             0.00000  [0.0, 0.0, 10.0]
# 1607           17.46240             0.00000   [0.0, 1.0, 9.0]
# 1608           19.88598             0.00000  [0.0, 0.0, 10.0]
# 1609           19.18358             0.00000  [0.0, 0.0, 10.0]
#
# [1610 rows x 11 columns]
# branches_df[rf.classes_[i]]:
# 0       9.0
# 1       8.0
# 2       6.0
# 3       6.0
# 4       6.0
#        ...
# 1605    0.0
# 1606    0.0
# 1607    0.0
# 1608    0.0
# 1609    0.0
# Name: setosa, Length: 1610, dtype: float64
#
# branches_df[rf.classes_[i]]:
# 0       1.0
# 1       2.0
# 2       4.0
# 3       3.0
# 4       4.0
#        ...
# 1605    0.0
# 1606    0.0
# 1607    1.0
# 1608    0.0
# 1609    0.0
# Name: versicolor, Length: 1610, dtype: float64
#
# branches_df[rf.classes_[i]]:
# 0        0.0
# 1        0.0
# 2        0.0
# 3        1.0
# 4        0.0
#         ...
# 1605    10.0
# 1606    10.0
# 1607     9.0
# 1608    10.0
# 1609    10.0
# Name: virginica, Length: 1610, dtype: float64
#
# branches_df_new:
#       0_upper  0_lower  1_upper  1_lower  2_upper  2_lower  3_upper  3_lower  \
# 0        5.45     -inf     2.15     -inf     2.45     -inf      0.7     -inf
# 1        5.45     -inf     2.15     -inf     2.60     2.45      0.7     -inf
# 2        5.05     -inf     2.15     -inf     3.90     2.60      0.7     -inf
# 3        5.05     -inf     2.15     -inf     4.85     3.90      0.7     -inf
# 4        5.45     5.05     2.15     -inf     4.85     2.60      0.7     -inf
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1605     6.00     5.95      inf     2.75      inf     4.95      inf      1.7
# 1606     6.45     6.00      inf     2.75     4.95     4.85      inf      1.7
# 1607     7.00     6.45      inf     2.75     4.95     4.85      inf      1.7
# 1608     7.00     6.00      inf     2.75      inf     4.95      inf      1.7
# 1609      inf     7.00      inf     2.75      inf     4.85      inf      1.7
#
#       number_of_samples  branch_probability            probas  setosa  \
# 0              23.92448             0.02344   [9.0, 1.0, 0.0]     9.0
# 1              19.35746             0.00000   [8.0, 2.0, 0.0]     8.0
# 2              12.94511             0.02344   [6.0, 4.0, 0.0]     6.0
# 3              12.94511             0.02344   [6.0, 3.0, 1.0]     6.0
# 4              18.94014             0.00000   [6.0, 4.0, 0.0]     6.0
# ...                 ...                 ...               ...     ...
# 1605           19.61608             0.00000  [0.0, 0.0, 10.0]     0.0
# 1606           17.46240             0.00000  [0.0, 0.0, 10.0]     0.0
# 1607           17.46240             0.00000   [0.0, 1.0, 9.0]     0.0
# 1608           19.88598             0.00000  [0.0, 0.0, 10.0]     0.0
# 1609           19.18358             0.00000  [0.0, 0.0, 10.0]     0.0
#
#       versicolor  virginica
# 0            1.0        0.0
# 1            2.0        0.0
# 2            4.0        0.0
# 3            3.0        1.0
# 4            4.0        0.0
# ...          ...        ...
# 1605         0.0       10.0
# 1606         0.0       10.0
# 1607         1.0        9.0
# 1608         0.0       10.0
# 1609         0.0       10.0
#
# [1610 rows x 14 columns]
