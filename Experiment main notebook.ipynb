# %%
import pandas as pd
import numpy as np
from ExperimentSetting import *
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
import os
import glob
warnings.filterwarnings('ignore')

# %%
branch_probability_thresholds=[3000]
filter_approaches = ['probability']
df_names = ['abalone', 'aust_credit', 'balance_scale', 'bank', 'banknote', 
            'biodeg', 'breast cancer', 'car', 'credit', 'cryotherapy', 'ecoli', 
            'forest', 'german', 'glass', 'haberman', 'internet', 'iris', 'kohkiloyeh',
            'liver', 'magic', 'mamographic', 'nurse', 'occupancy', 'pima', 'seismic', 
            'spambase', 'tic-tac-toe', 'vegas', 'winery', 'zoo']
df_names = ['iris']
number_of_estimators=100
fixed_params={}
num_of_iterations=1

e = ExperimentSetting(branch_probability_thresholds,df_names,
                      number_of_estimators,fixed_params, num_of_iterations)

# %%
folder_path = 'pickles_200trees'
files = glob.glob(os.path.join(folder_path, '*'))
# 逐个删除文件
for file in files:
    try:
        os.remove(file)
        print(f"Deleted: {file}")
    except Exception as e:
        print(f"Error deleting {file}: {e}")
e.run()
# Out:
# {'max_number_of_branches': 3000, 'df_name': 'iris', 'number_of_estimators': 100}
# 0
# 1.0 [1, 92]
# 1.0 [1, 92, 0]
# 1.0 [1, 92, 0, 2]
# 1.0 [1, 92, 0, 2, 5]
# 1.0 [1, 92, 0, 2, 5, 7]
# 1.0 [1, 92, 0, 2, 5, 7, 3]
# 1.0 [1, 92, 0, 2, 5, 7, 3, 4]
# 1.0 [1, 92, 0, 2, 5, 7, 3, 4, 6]
# 1.0 [1, 92, 0, 2, 5, 7, 3, 4, 6, 8]
# Finish pruning
# Iteration 1: 7 conjunctions
# Iteration 2: 31 conjunctions
# Iteration 3: 65 conjunctions
# Iteration 4: 158 conjunctions
# Iteration 5: 200 conjunctions
# Iteration 6: 285 conjunctions
# Iteration 7: 454 conjunctions
# Iteration 8: 708 conjunctions
# Iteration 9: 1031 conjunctions
# Final CS size: 1558
# branches_df:
#       0_upper  0_lower  1_upper  1_lower  2_upper  2_lower  3_upper  3_lower  \
# 0        4.70     -inf     2.70     -inf     2.35     -inf     0.75     -inf
# 1        4.70     -inf     2.70     -inf     2.70     2.35     0.75     -inf
# 2        4.70     -inf     2.70     -inf     4.75     2.70     0.75     -inf
# 3        4.70     -inf     2.70     -inf     4.85     4.75     0.75     -inf
# 4        4.70     -inf     2.65     -inf     4.95     4.85     0.75     -inf
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1553     7.00     6.15      inf     2.75      inf     5.25     1.85     1.75
# 1554     7.00     6.15      inf     2.75      inf     5.25      inf     1.85
# 1555     7.05     7.00      inf     2.75      inf     5.25     1.85     1.75
# 1556     7.05     7.00      inf     2.75      inf     5.25      inf     1.85
# 1557      inf     7.05      inf     2.75      inf     5.25      inf     1.75
#
#       number_of_samples  branch_probability  \
# 0             25.863444                 0.0
# 1              5.072239                 0.0
# 2              5.127708                 0.0
# 3              8.881450                 0.0
# 4              5.969768                 0.0
# ...                 ...                 ...
# 1553          10.403939                 0.0
# 1554          13.042027                 0.0
# 1555           8.358820                 0.0
# 1556          10.478335                 0.0
# 1557           7.064492                 0.0
#
#                                            probas
# 0                                [10.0, 0.0, 0.0]
# 1                                 [9.0, 1.0, 0.0]
# 2                                 [8.0, 2.0, 0.0]
# 3                                 [8.0, 1.6, 0.4]
# 4                                 [8.0, 1.6, 0.4]
# ...                                           ...
# 1553  [0.0, 0.1111111111111111, 9.88888888888889]
# 1554                             [0.0, 0.0, 10.0]
# 1555  [0.0, 0.1111111111111111, 9.88888888888889]
# 1556                             [0.0, 0.0, 10.0]
# 1557                             [0.0, 0.0, 10.0]
#
# [1558 rows x 11 columns]
# branches_df[rf.classes_[i]]:
# 0       10.0
# 1        9.0
# 2        8.0
# 3        8.0
# 4        8.0
#         ...
# 1553     0.0
# 1554     0.0
# 1555     0.0
# 1556     0.0
# 1557     0.0
# Name: setosa, Length: 1558, dtype: float64
#
# branches_df[rf.classes_[i]]:
# 0       0.000000
# 1       1.000000
# 2       2.000000
# 3       1.600000
# 4       1.600000
#           ...
# 1553    0.111111
# 1554    0.000000
# 1555    0.111111
# 1556    0.000000
# 1557    0.000000
# Name: versicolor, Length: 1558, dtype: float64
#
# branches_df[rf.classes_[i]]:
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        0.400000
# 4        0.400000
#           ...
# 1553     9.888889
# 1554    10.000000
# 1555     9.888889
# 1556    10.000000
# 1557    10.000000
# Name: virginica, Length: 1558, dtype: float64
#
# branches_df_new:
#       0_upper  0_lower  1_upper  1_lower  2_upper  2_lower  3_upper  3_lower  \
# 0        4.70     -inf     2.70     -inf     2.35     -inf     0.75     -inf
# 1        4.70     -inf     2.70     -inf     2.70     2.35     0.75     -inf
# 2        4.70     -inf     2.70     -inf     4.75     2.70     0.75     -inf
# 3        4.70     -inf     2.70     -inf     4.85     4.75     0.75     -inf
# 4        4.70     -inf     2.65     -inf     4.95     4.85     0.75     -inf
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1553     7.00     6.15      inf     2.75      inf     5.25     1.85     1.75
# 1554     7.00     6.15      inf     2.75      inf     5.25      inf     1.85
# 1555     7.05     7.00      inf     2.75      inf     5.25     1.85     1.75
# 1556     7.05     7.00      inf     2.75      inf     5.25      inf     1.85
# 1557      inf     7.05      inf     2.75      inf     5.25      inf     1.75
#
#       number_of_samples  branch_probability  \
# 0             25.863444                 0.0
# 1              5.072239                 0.0
# 2              5.127708                 0.0
# 3              8.881450                 0.0
# 4              5.969768                 0.0
# ...                 ...                 ...
# 1553          10.403939                 0.0
# 1554          13.042027                 0.0
# 1555           8.358820                 0.0
# 1556          10.478335                 0.0
# 1557           7.064492                 0.0
#
#                                            probas  setosa  versicolor  \
# 0                                [10.0, 0.0, 0.0]    10.0    0.000000
# 1                                 [9.0, 1.0, 0.0]     9.0    1.000000
# 2                                 [8.0, 2.0, 0.0]     8.0    2.000000
# 3                                 [8.0, 1.6, 0.4]     8.0    1.600000
# 4                                 [8.0, 1.6, 0.4]     8.0    1.600000
# ...                                           ...     ...         ...
# 1553  [0.0, 0.1111111111111111, 9.88888888888889]     0.0    0.111111
# 1554                             [0.0, 0.0, 10.0]     0.0    0.000000
# 1555  [0.0, 0.1111111111111111, 9.88888888888889]     0.0    0.111111
# 1556                             [0.0, 0.0, 10.0]     0.0    0.000000
# 1557                             [0.0, 0.0, 10.0]     0.0    0.000000
#
#       virginica
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.400000
# 4      0.400000
# ...         ...
# 1553   9.888889
# 1554  10.000000
# 1555   9.888889
# 1556  10.000000
# 1557  10.000000
#
# [1558 rows x 14 columns]
# branches_df['probas'].mean()
# [1.44159178 4.67768507 3.88072315]
# df_dict[col]:
# <class 'numpy.ndarray'>
# [4.7  4.7  4.7  ... 7.05 7.05  inf]
# df_dict[col]:
# <class 'numpy.ndarray'>
# [-inf -inf -inf ... 7.   7.   7.05]
# df_dict[col]:
# <class 'numpy.ndarray'>
# [2.7 2.7 2.7 ... inf inf inf]
# df_dict[col]:
# <class 'numpy.ndarray'>
# [-inf -inf -inf ... 2.75 2.75 2.75]
# df_dict[col]:
# <class 'numpy.ndarray'>
# [2.35 2.7  4.75 ...  inf  inf  inf]
# df_dict[col]:
# <class 'numpy.ndarray'>
# [-inf 2.35 2.7  ... 5.25 5.25 5.25]
# df_dict[col]:
# <class 'numpy.ndarray'>
# [0.75 0.75 0.75 ... 1.85  inf  inf]
# df_dict[col]:
# <class 'numpy.ndarray'>
# [-inf -inf -inf ... 1.75 1.85 1.75]
# df_dict[col]:
# <class 'numpy.ndarray'>
# [25.863444  5.072239  5.127708 ...  8.35882  10.478335  7.064492]
# df_dict[col]:
# <class 'numpy.ndarray'>
# [0. 0. 0. ... 0. 0. 0.]
# df_dict[col]:
# <class 'numpy.ndarray'>
# [array([10.,  0.,  0.]) array([9., 1., 0.]) array([8., 2., 0.]) ...
#  array([0.        , 0.11111111, 9.88888889]) array([ 0.,  0., 10.])
#  array([ 0.,  0., 10.])]
# df_dict[col]:
# <class 'numpy.ndarray'>
# [10.  9.  8. ...  0.  0.  0.]
# df_dict[col]:
# <class 'numpy.ndarray'>
# [0.         1.         2.         ... 0.11111111 0.         0.        ]
# df_dict[col]:
# <class 'numpy.ndarray'>
# [ 0.          0.          0.         ...  9.88888889 10.
#  10.        ]
